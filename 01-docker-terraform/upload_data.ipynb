# %%
import pandas as pd
from sqlalchemy import create_engine

# Подключение (используем localhost, так как запускаем из терминала)
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

print("Загружаем зоны...")
df_zones = pd.read_csv('taxi_zone_lookup.csv')
df_zones.to_sql(name='zones', con=engine, if_exists='replace', index=False)

print("Загружаем данные такси за НОЯБРЬ 2025...")
# Используем fastparquet, чтобы избежать ошибки ArrowKeyError
df = pd.read_parquet('green_tripdata_2025-11.parquet', engine='fastparquet')

# Загружаем всё в базу
df.to_sql(name='green_taxi_data', con=engine, if_exists='replace', index=False)

print("ГОТОВО! База чиста и наполнена Ноябрем 2025.")
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[4], line 9
#       5 engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
#       7 # Читаем Parquet файл
#       8 # Если ты скачал green_tripdata_2019-10.parquet, укажи это имя
# ----> 9 df = pd.read_parquet('green_tripdata_2019-10.parquet')
#      11 # Загружаем в Postgres
#      12 # if_exists='replace' полностью перезапишет старую таблицу новыми данными
#      13 df.to_sql(name='green_taxi_data', con=engine, if_exists='replace', index=False)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/io/parquet.py:653, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     500 @doc(storage_options=_shared_docs["storage_options"])
#     501 def read_parquet(
#     502     path: FilePath | ReadBuffer[bytes],
#    (...)    510     **kwargs,
#     511 ) -> DataFrame:
#     512     """
#     513     Load a parquet object from the file path, returning a DataFrame.
#     514
#    (...)    650     1    4    9
#     651     """
# --> 653     impl = get_engine(engine)
#     655     if use_nullable_dtypes is not lib.no_default:
#     656         msg = (
#     657             "The argument 'use_nullable_dtypes' is deprecated and will be removed "
#     658             "in a future version."
#     659         )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/io/parquet.py:64, in get_engine(engine)
#      62 for engine_class in engine_classes:
#      63     try:
# ---> 64         return engine_class()
#      65     except ImportError as err:
#      66         error_msgs += "\n - " + str(err)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/io/parquet.py:170, in PyArrowImpl.__init__(self)
#     167 import pyarrow.parquet
#     169 # import utils to register the pyarrow extension types
# --> 170 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     172 self.api = pyarrow
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/arrays/arrow/extension_types.py:174
#     167     pyarrow.register_extension_type(
#     168         ForbiddenExtensionType(pyarrow.null(), "arrow.py_extension_type")
#     169     )
#     171     pyarrow._hotfix_installed = True
# --> 174 patch_pyarrow()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/arrays/arrow/extension_types.py:166, in patch_pyarrow()
#     157         pickletools.dis(serialized, out)
#     158         raise RuntimeError(
#     159             _ERROR_MSG.format(
#     160                 storage_type=storage_type,
#    (...)    163             )
#     164         )
# --> 166 pyarrow.unregister_extension_type("arrow.py_extension_type")
#     167 pyarrow.register_extension_type(
#     168     ForbiddenExtensionType(pyarrow.null(), "arrow.py_extension_type")
#     169 )
#     171 pyarrow._hotfix_installed = True
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pyarrow/types.pxi:2280, in pyarrow.lib.unregister_extension_type()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowKeyError: No type extension with name arrow.py_extension_type found
